# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib.font_manager import FontProperties
import pandas as pd
 
'''Read csv file '''
def readcsv(files):
    csvfile = open(files, 'r')
    plots = pd.read_csv(csvfile)

    return plots
 
    
    
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'NSimSun,Times New Roman'
 

data =readcsv("run-2021-06-19_20-13-15_SAC_Walker2DBulletEnv-v0_Gaussian_num_m1_num_q2_updates_per_step1-tag-avg_reward_test.csv")
print(x2,y2)

plt.plot(data['Step'].astype(int), data['Value'].astype(int), color='red', label='Default')

plt.xlabel('Steps',fontsize=20)
plt.ylabel('Score',fontsize=20)
plt.legend(fontsize=16)
plt.show()
# Out:
# [] []
